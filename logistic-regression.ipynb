# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/7_logistic_reg/insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age, df.bought_insurance, color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, train_size=0.9)

# %%
x_test
# Out:
#     age
# 14   49
# 15   55
# 26   23

# %%
x_train
# Out:
#     age
# 23   45
# 24   50
# 19   18
# 17   58
# 3    52
# 0    22
# 12   27
# 5    56
# 9    61
# 25   54
# 8    62
# 10   18
# 6    55
# 16   25
# 20   21
# 13   29
# 7    60
# 2    47
# 22   40
# 1    25
# 18   19
# 4    46
# 11   28
# 21   26

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 1, 0], dtype=int64)

# %%
x_test
# Out:
#     age
# 14   49
# 15   55
# 26   23

# %%
y_test
# Out:
# 14    1
# 15    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(x_test)
# Out:
# array([[0.23072913, 0.76927087],
#        [0.12410236, 0.87589764],
#        [0.88549799, 0.11450201]])

# %%
#exercise
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/7_logistic_reg/Exercise/HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df = df.drop('Department', axis='columns')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df = df.drop('last_evaluation', axis='columns')
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 14994                0.40               2                   151
# 14995                0.37               2                   160
# 14996                0.37               2                   143
# 14997                0.11               6                   280
# 14998                0.37               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  salary
# 0                       3              0     1                      0     low
# ...

# %%
df = df.drop('Work_accident', axis='columns')
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 14994                0.40               2                   151
# 14995                0.37               2                   160
# 14996                0.37               2                   143
# 14997                0.11               6                   280
# 14998                0.37               2                   158
#
#        time_spend_company  left  promotion_last_5years  salary
# 0                       3     1                      0     low
# 1                       6     1                      0  medium
# ...

# %%
df.promotion_last_5years.mean()
# Out:
# 0.021268084538969265

# %%
dummy_sals = pd.get_dummies(df.salary)
dummy_sals
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
df = pd.concat([df, dummy_sals], axis='columns')

# %%
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 14994                0.40               2                   151
# 14995                0.37               2                   160
# 14996                0.37               2                   143
# 14997                0.11               6                   280
# 14998                0.37               2                   158
#
#        time_spend_company  left  promotion_last_5years  salary  high  low  \
# 0                       3     1                      0     low     0    1
# ...

# %%
df.drop("medium", axis='columns')
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 14994                0.40               2                   151
# 14995                0.37               2                   160
# 14996                0.37               2                   143
# 14997                0.11               6                   280
# 14998                0.37               2                   158
#
#        time_spend_company  left  promotion_last_5years  salary  high  low
# 0                       3     1                      0     low     0    1
# ...

# %%
df = df.drop('salary', axis='columns')
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 14994                0.40               2                   151
# 14995                0.37               2                   160
# 14996                0.37               2                   143
# 14997                0.11               6                   280
# 14998                0.37               2                   158
#
#        time_spend_company  left  promotion_last_5years  high  low  medium
# 0                       3     1                      0     0    1       0
# ...

# %%
df.groupby('left').mean()
# Out:
#       satisfaction_level  number_project  average_montly_hours  \
# left
# 0               0.666810        3.786664            199.060203
# 1               0.440098        3.855503            207.419210
#
#       time_spend_company  promotion_last_5years      high       low
# left
# 0               3.380032               0.026251  0.101068  0.450123
# 1               3.876505               0.005321  0.022963  0.608233

# %%
df = df.drop('medium', axis='columns')
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 14994                0.40               2                   151
# 14995                0.37               2                   160
# 14996                0.37               2                   143
# 14997                0.11               6                   280
# 14998                0.37               2                   158
#
#        time_spend_company  left  promotion_last_5years  high  low
# 0                       3     1                      0     0    1
# ...

# %%
independent = df.drop('left', axis='columns')
X_train, X_test, y_train, y_test = train_test_split(independent, df.left, test_size=0.2)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(X_test, y_test)
# Out:
# 0.781
